# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/Sande/Desktop/bankmarketing.csv")

# %%
df.sample(5)
# Out:
#        age           job   marital            education  default  housing  \
# 15633   27    technician    single  professional.course       no       no
# 11740   36        admin.   married    university.degree       no  unknown
# 30849   45  entrepreneur  divorced             basic.9y       no      yes
# 2475    51   blue-collar   married             basic.4y  unknown       no
# 22415   33        admin.   married    university.degree       no       no
#
#           loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 15633       no   cellular   jul         mon  ...         7    999         0
# 11740  unknown  telephone   jun         fri  ...         2    999         0
# 30849       no   cellular   may         tue  ...         3    999         0
# 2475        no  telephone   may         tue  ...         2    999         0
# 22415       no   cellular   aug         fri  ...         1    999         0
#
# ...

# %%
sns.barplot(x = df['job'], y=df['age'],  estimator = np.median)
# Out:
# <Axes: xlabel='job', ylabel='age'>

# %%
sns.boxplot(x = df['job'], y= df['age'])
# Out:
# <Axes: xlabel='job', ylabel='age'>

# %%
sns.barplot(x = df['job'], y=df['nr.employed'],  estimator = np.median)
# Out:
# <Axes: xlabel='job', ylabel='nr.employed'>

# %%
sns.boxplot(x = df['job'], y=df['nr.employed'])
# Out:
# <Axes: xlabel='job', ylabel='nr.employed'>

# %%
print(f"day of week :->\n{df['day_of_week'].value_counts()}")
print()
print(f"month:->\n{df['month'].value_counts()}")
print()
print(f"contaact :->\n{df['contact'].value_counts()}")
print()
print(f"education :->\n{df['education'].value_counts()}")
print()
print(f"marital :->\n{df['marital'].value_counts()}")
print()
print(f"job->\n{df['job'].value_counts()}")
# Out:
# day of week :->
# day_of_week
# thu    8623
# mon    8514
# wed    8134
# tue    8090
# fri    7827
# Name: count, dtype: int64
#
# month:->
# month
# may    13769
# jul     7174
# aug     6178
# jun     5318
# nov     4101
# apr     2632
# oct      718
# sep      570
# mar      546
# dec      182
# Name: count, dtype: int64
#
# contaact :->
# contact
# cellular     26144
# telephone    15044
# Name: count, dtype: int64
#
# education :->
# education
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: count, dtype: int64
#
# marital :->
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64
#
# job->
# job
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# ...

# %%
sns.heatmap(pd.crosstab(df['job'], df['age']))
# Out:
# <Axes: xlabel='age', ylabel='job'>

# %%
sns.heatmap(pd.crosstab(df['marital'], df['previous']))
# Out:
# <Axes: xlabel='previous', ylabel='marital'>

# %%
df.sample(1)
# Out:
#        age     job  marital          education default housing loan   contact  \
# 37745   54  admin.  married  university.degree      no     yes  yes  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 37745   aug         fri  ...         1    999         1   failure
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# 37745         -2.9          92.201          -31.4      0.849       5076.2  yes
#
# [1 rows x 21 columns]

# %%
sns.scatterplot(x = df['age'],y = df['cons.price.idx'])
# Out:
# <Axes: xlabel='age', ylabel='cons.price.idx'>

# %% [markdown]
# Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.pairplot(df)
